# %% [markdown]
# Importing various libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import model_selection

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# Importing the Dataset

# %%
df = pd.read_csv("/content/framingham.csv")

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# Data Pre - processing

# %%
df.shape
# Out:
# (4240, 16)

# %%
df.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
df.tail(10)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4230     0   56        1.0              1         3.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4230                0             1         0    268.0  170.0  102.0  22.89
# 4231                0             1         0    187.0  141.0   81.0  24.96
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.drop(['education'], inplace  =True, axis = 1)

# %%
df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4235     0   48              1        20.0     NaN                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
df.dropna(axis = 0, inplace = True) # this drops all rows which have column values as NaN

# %%
df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4233     1   50              1         1.0     0.0                0
# 4234     1   51              1        43.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.groupby('TenYearCHD').sum()
# Out:
#             male     age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# TenYearCHD
# 0           1351  154918           1538     27739.0    77.0               13
# 1            319   31032            294      6052.0    37.0                8
#
#             prevalentHyp  diabetes   totChol     sysBP     diaBP       BMI  \
# TenYearCHD
# 0                    880        66  747804.0  414256.5  261264.5  81581.90
# 1                    290        36  140913.0   82257.5   49838.0  15224.99
#
#             heartRate   glucose
# TenYearCHD
# 0            240298.0  256300.0
# 1             43668.0   50832.0

# %%
df.groupby('TenYearCHD').size()
# Out:
# TenYearCHD
# 0    3179
# 1     572
# dtype: int64

# %%
df.groupby('male').size()
# Out:
# male
# 0    2081
# 1    1670
# dtype: int64

# %%
df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4233     1   50              1         1.0     0.0                0
# 4234     1   51              1        43.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
df.describe()
# Out:
#               male          age  currentSmoker   cigsPerDay       BPMeds  \
# count  3751.000000  3751.000000    3751.000000  3751.000000  3751.000000
# mean      0.445215    49.573447       0.488403     9.008531     0.030392
# std       0.497056     8.570204       0.499932    11.925097     0.171686
# min       0.000000    32.000000       0.000000     0.000000     0.000000
# 25%       0.000000    42.000000       0.000000     0.000000     0.000000
# 50%       0.000000    49.000000       0.000000     0.000000     0.000000
# 75%       1.000000    56.000000       1.000000    20.000000     0.000000
# max       1.000000    70.000000       1.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol        sysBP  \
# count      3751.000000   3751.000000  3751.000000  3751.000000  3751.000000
# mean          0.005599      0.311917     0.027193   236.928019   132.368435
# std           0.074623      0.463338     0.162666    44.611594    22.046522
# ...

# %% [markdown]
# Splitting the dataset into test and train sets

# %%
#Independent variable

X = df[['age', 'male', 'cigsPerDay','totChol', 'sysBP', 'glucose']]

#Dependent variables
Y = df.iloc[:,-1]

# %%
#splitting the model into train,test and split

# %%
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X,Y, test_size = 0.3, random_state = 4)

# %%
print("Train set:" ,X_train.shape, Y_train.shape)
print("Test set:" ,X_test.shape, Y_test.shape)
# Out:
# Train set: (2625, 6) (2625,)
# Test set: (1126, 6) (1126,)

# %%
sns.countplot(x = 'TenYearCHD', data = df)
plt.show()

# %% [markdown]
# Define and fitting the model

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()

# %%
logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Predicting on Test data set

# %%
prediction = logreg.predict(X_test)

# %%
print(prediction)
# Out:
# [0 0 0 ... 0 0 0]

# %% [markdown]
# Finding the accuracy of the model

# %%
from sklearn import metrics

print(metrics.accuracy_score(Y_test,prediction))
# Out:
# 0.8490230905861457

# %% [markdown]
# Finding the Confusion matrix

# %%
cm = metrics.confusion_matrix(Y_test,prediction)
print(cm)
# Out:
# [[942   9]
#  [161  14]]

# %%
fig = plt.figure(figsize = (10,5))

sns.heatmap(cm,xticklabels = ['Predicted:1', 'Predicted:0'], yticklabels = ['Actual:1', 'Actual:0'], cmap = 'Greens', annot = True, fmt ='d')
plt.show()

# %% [markdown]
# Printing the calssification report

# %%
print(metrics.classification_report(Y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       951
#            1       0.61      0.08      0.14       175
#
#     accuracy                           0.85      1126
#    macro avg       0.73      0.54      0.53      1126
# weighted avg       0.82      0.85      0.80      1126

# %% [markdown]
# The model performs well at predicting no heart disease (class 0) but poorly predicts heart disease (class 1) resulting in an imbalanced classification performance. To enhance model performance techniques such as class balancing, adjusting thresholds or experimenting with different algorithms could help in achieving better results particularly in correctly identifying individuals with heart disease.
